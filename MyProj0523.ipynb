# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.nkust.edu.tw/p/406-1000-69684,r1363.php"
html = requests.get(url).text

# %%
soup = BeautifulSoup(html, "html.parser")
sel = "#Dyn_2_3 > div.module.module-detail.md_style1 > div > section > div.mcont > div.mpgdetail > p"
content = soup.select(sel)
data = content[0]
data.text
# Out:
# '2050年前全球達到淨零排放的目標，現已為世界各國的重點發展政策。全球企業在工業的領域上，業已進入綠色工業革命的時代。國立高雄科技大學串連校內各領域教師之創新科研成果，並集結於參與「2023高雄自動化工業展」，在高雄展覽館設立高科大專區，展出涵蓋產業機械、永續能源、低碳製程、循環經濟、負碳技術及創新發明等33件教師研發技術與設備，除協助參觀廠商民眾了解淨零永續的趨勢，也積極開拓可加入產學輔導或技轉的企業對象。\n\n今年展出技術，涵蓋產業機械設備以及創新發明，多項作品均高度應用資訊收集、判讀等AI應用，例如具生醫檢測之智慧翻身輔具；影像辨識自動化多樣本化學檢測系統；神經網路視覺辨識應用於複合材料FRP之VARTM製程樹脂瞬時流速觀測；可線上量測並紀錄刀刃即時變化情況的智慧刀把等。特別是後者智慧刀把，使用在金屬切削加工上，不少需要精密加工的高值產品均可受惠，智慧刀把可同時確認加工件的加工成品品質、回饋刀具的狀態以利產線做出及時替換，減少產品問題或刀具損壞等成本損失。\n\n智慧刀把研發老師為高科大電機系教授楊浩青，他表示智慧刀把對高價值、高精密的加工領域非常重要，根據實際統計，由於擔心產品失敗率而導致刀具的替換率過高，正確回推的話，淘汰刀具的剩餘價值甚至最多高達85%。因此智慧刀把除可有效確保加工品質外，也能精準掌握刀具狀況充分發揮刀具使用價值，並且減少操作人員擔心損壞高成本工具及產品的心理壓力。據了解，以德國生產的類似產品而言，售價高達台幣50萬元，由高科大自主開發的智慧刀把，從硬體部件到軟體開發，完全台灣自產，有非常雄厚的售價優勢，對精密加工業者而言是一大福音。\n\n其它還包含強化火場逃生及滅火的目的的輔助滅火窗、煙室人員透氣逃生窗等發明，正呼應近期消防法保障消防人員權益的修法方向，並且可提高滅火效率，實現「不進火場、有效輔助打火」的目標。另外可純生物分解的高分子聚合物、碳纖維回收料的技術、微奈米氣泡浮除及清洗系統、無爆炸疑慮的安全儲電系統、電解產氫、海水發電產氫等等，均高度呼應當前環境保護、淨零探排、能源永續的重要趨勢。高科大校長楊慶煜表示，產業的升級與轉型也是高科大實踐社會責任的重要一環，任何創新研發、技術移轉、產學合作等相關產業需求，高科大都非常樂意與企業站在一起，共同提升台灣產業競爭力。高雄自動化工業展將展出至本週六 (5月20日)，於高雄展覽館展出。'

# %%
import jieba
fp = open("alldata.txt","r",encoding="utf-8")
alldata = fp.read()
tt = jieba.cut(alldata)
terms = list()
for t in tt:
    terms.append(t)
alldata = ",".join(terms)
alldata
# Out:
# '2050,年前,全球,達到,淨,零排放,的,目標,，,現已,為,世界,各國,的,重點,發展,政策,。,全球,企業,在,工業,的,領域,上,，,業已,進入,綠色,工業,革命,的,時代,。,國立,高雄,科技,大學串,連校,內,各,領域,教師,之,創新,科研成果,，,並集結,於,參,與,「,2023,高雄,自動,化工,業展,」,，,在,高雄,展覽館,設立,高,科大,專區,，,展出,涵蓋產業,機械,、,永續,能源,、,低,碳,製,程,、,循環,經濟,、,負碳,技術,及,創新,發明,等,33,件,教師,研發,技術,與,設備,，,除協助,參觀,廠,商民,眾,了解,淨零永續,的,趨勢,，,也,積極,開拓,可,加入,產學,輔導,或,技轉,的,企業,對象,。,\n,\n,今年,展出,技術,，,涵蓋產業,機械,設備,以及,創新,發明,，,多項,作品,均,高度,應用,資訊,收集,、,判讀,等,AI,應用,，,例如,具生,醫檢測,之,智慧,翻身,輔具,；,影像,辨識,自動化,多樣,本化學,檢測,系統,；,神經,網路視,覺辨識,應用,於,複,合,材料,FRP,之,VARTM,製,程,樹,脂,瞬,時,流速,觀測,；,可線,上量,測並,紀錄,刀刃,即時,變化,情況,的,智慧,刀把,等,。,特別,是後者,智慧,刀把,，,使用,在,金屬,切削,加工,上,，,不少,需要,精密,加工,的,高值,產品,均,可,受惠,，,智慧,刀把,可同時,確認,加工件,的,加工,成品,品質,、,回饋,刀具,的,狀態,以利,產線,做出,及時,替換,，,減少產品,問題,或,刀具,損壞,等,成本,損失,。,\n,\n,智慧,刀把,研發,老師,為,高,科大,電機系,教授,楊浩青,，,他,表示,智慧,刀把,對,高價值,、,高精密,的,加工,領域,非常,重要,，,根據,實際,統計,，,由,於,擔心,產品,失敗率,而,導致,刀具,的,替,換率,過高,，,正確,回,推,的,話,，,淘汰,刀具,的,剩餘價值,甚至,最多,高達,85%,。,因此,智慧,刀把,除,可,有效,確保,加工品,質外,，,也,能,精準,掌握,刀具,狀況,充分,發揮,刀具,使用,價值,，,並且,減少,操作,人員,擔心,損壞,高,成本,工具,及產品,的,心理,壓力,。,據,了解,，,以德,國生產,的,類似,產品,而言,，,售價,高達,台幣,50,萬元,，,由,高,科大,自主,開發,的,智慧,刀把,，,從,硬體,部件,到,軟體,開發,，,完全,台灣,自產,，,有,非常,雄厚,的,售價,優勢,，,對,精密,加工,業者,而言,是,一大,福音,。,\n,\n,其它,還,包含,強化,火場,逃生,及滅,火,的,目的,的,輔助滅,火窗,、,煙室,人員,透氣,逃生,窗等,發明,，,正呼應,近期,消防法,保障,消防人,員權益,的,修法,方向,，,並且,可,提高,滅火,效率,，,實現,「,不進,火場,、,有效,輔助,打火,」,的,目標,。,另外,可純,生物,分解,的,高分子,聚合物,、,碳纖維,回收,料,的,技術,、,微奈米,氣泡,浮除,及,清洗,系統,、,無,爆炸,疑慮,的,安全,儲電系統,、,電解產氫,、,海水,發電產氫,等等,，,均,高度,呼應,當前,環境,保護,、,淨零,探排,、,能源,永續,的,重要,趨勢,。,高科,大校,長,楊慶煜,表示,，,產業,的,升級,與,轉型,也,是,高,科大,實踐,社會責任,的,重要,一環,，,任何,創新,研發,、,技術,移轉,、,產學,合作,等,相關,產業,需求,，,高科,大都,非常,樂意,與,企業,站,在,一起,，,共同,提升,台灣產業,競爭力,。,高雄,自動,化工,業展將,展出,至本,週六, ,(,5,月,20,日,),，,於,高雄,展覽館,展出,。,國立,高雄,科技,大學,環境,與,安全,衛生,工程系,，,本月,5,日連續,第八年,舉辦,環境,安全,衛生,暨,消防工程,研討會,，,集結近,90,篇論,文發表,，,含括,環境,保護,、,工業,安全,、,職業,衛生,及,消防工程,等,多項,環境,相關,議題,，,展現,高,科大,透過,學術,專業,，,積極,在,環境,永續,的,議題,上,，,與,社區,環境,共,好,，,積極,提出,解決,方案,。,由策,展人游,明龍,促成,的,「,山水,吟遊,—,游登良,攝,影展,」,，,與,國內,詩文,、,書藝大師,跨界,合作,，,創,作出,一系列,充滿,視覺,震撼,與,文學,感動,的,展品,，,現,於,國立,高雄,科技,大學,建工,校區,藝文,中心,展出,中,。,山水,吟遊,展覽,以游,登良,的,自然,攝影,為,基礎,，,結合林章,湖,、,蕭世瓊,、,陳,岸,三位,國內書藝,大家,，,將國家,公園,震撼人心,的,影像,作品,結合,文學,意境,，,呈現,嶄,新,的,跨界,藝術表現,，,4,月,29,日舉,辦,開幕,茶會,以及,講座,，,吸引,南,臺,灣眾,多,畫會,、,藝術家,及,藏家,到場,。,國立,高雄,科技,大學,是,教育部,苗圃,計畫,的,分區,資源,中心,，,日前,於,4,月,15,及,16,日舉,辦,「,跨計畫,教師,交流,會,」,及,「,議題,場域,探查,活動,」,，,藉由,交流,活動,分享,高,科大,承接,教育部,苗圃,計畫,四年,來,的,經驗,。,首日,邀請,高,科大,高瞻,科技,不分系,張鐵懷,老師,及,高,科大,創新,創業,教育,中心,陳,建志,老師,，,與,中南部,各大專,院校,師資,分享,及,交流,，,幫助,各校,了解,工作坊,辦理,模式,，,甚至,促成,多場,人,培工坊,及師,培工坊,。,高,科大,副,校長,謝淑玲,指出,，,苗圃,計畫,最,終要,達成,思考,的,延伸,，,也,就是,藉由,探查,場域,、,進行,工坊,、,導入,設計,思考,產生,想法,的,過程,之,後,，,要能,繼續,如,漣漪,擴散,，,延伸,思考,的,成果,，,向下,開,展出,更,多,研究,、,競賽,、,產學,等,各類,專案,。,適燃性,固體,廢棄物,轉換,為,能源,產品,，,國內龍,頭業者,隆順,綠能,科技,回到,娘家,高雄,和,發產業,園區,設置,二廠,，,預計,年底,可,投產,，,將成,在,台,最大,產區,。,隆順,核心,技術,可,1,:,1,將廢棄物,轉換,為,燃燒,棒,提供,能源,，,是,國內,首家,以,「,固體,再生,燃料,」,(,SRF,),登記,的,合法,工廠,，,其關鍵,技術,可,百分之百,將廢,塑膠,、,廢紡織品,轉換成,無,汙染,並,符合,國際,最高,標準,的,燃燒,棒,，,且,過程,中,無,添加,黏著劑,。,由高雄,科技,大學,環境,與,安全,衛生,工程系,教授,戴華山,提供,技術,指導,，,隆順,是,全國,首家,且,最大,的,循環,經濟,企業,，,它們,的,每,一步,都,引人注目,。,國立,高雄,科技,大學,行銷,與,流通,管理系,自,2020,年,起,，,舉辦,一系列,「,流通,大師,經典,講座,」,，,迄今,（,2023,年,）,已,邀,請,多位,國內,知名,流通,業大師,蒞臨,高科,大校,園演講,。,2020,年,先,由,流通,業,教父, ,徐重仁,董事,長,拉開,序幕,，,後,續,並陸續,邀請,到,美廉社, ,邱光隆,總經理,、,王品,集團, ,李森斌,副,董事,長,、,台灣,無,印良品, ,梁益,嘉,總經理,、,漢神百貨,暨漢神,巨蛋, ,南野雄介,總經理,、,全家,便利商店, ,葉榮廷,董事,長,、,全聯,福利,中心, ,謝健南,副,董事,長,、,好市,多,（,Costco,）, ,張嗣漢亞,太區,總裁,、,路易莎,咖啡, ,黃,明賢,董事,長,，,蒞臨,本校,第一,校區,與,全校,師生,分享,成功,的,經營,策略,與,實戰,經驗,，,以,吸引,更多,優秀,的,學子,加入,流通,產業,。,高雄,科技,大學,創新,創業,教育,中心,主辦,「,2023,設計,未來式,」,，,今年,攜手,壽山動物,園舉,辦動物,衍生,商品,提案,競賽,，,向,全國大專,院校,的,學生,招手,，,參賽,報名,5,月,1,日,截止,，,預計,今年,9,月份,將可選,出二組,商品,進行量,產,。,日前,於,4,月,10,日舉,辦,一日,遊園,體驗營,，,已有,27,個,隊伍,報名,參加,。,寵物,是,許多,現代人,生活,中,不可,缺乏,的,良伴,，,加上,步入,少子,化,、,高齡化,的,社會,，,寵物,更是,維持社,交互,動,、,支援,身心健康,的,重要,資源,，,成為,維,繫,社,會,健康,的,正面,力量,。,這股,趨勢,也,養出,龐大,的,寵物,商機,，,因此,高雄,科技,大學,海洋,科技,發展,處結,合水,產,食品,科學系,的,研究,能量,，,與,頂,麻吉寵物,食品,有限公司,簽定,「,寵物,新穎性,食品,技術,與,產品,研發,暨,人才,培育,合作意向,書,」,，,將在,寵物,市場,導入,永續,、,環保,、,社會責任,等,範疇,的,議題,，,提升,寵物,食品,的,研發,品質,。,亞洲,開發,銀行, ,(,Asian, ,Development, ,Bank,,, ,ADB,), ,執行,董事,柳尚玟,以及,財政部,派,駐,ADB,代表,侯旭娟,於,本月,27,日,回訪,高雄,科技,大學,，,走訪,高,科大,第一,及,楠梓,校區,，,參觀,高,科大,創夢,工場,，,以及,養殖,、,水產,相關,研究,教學,成果,。,高,科大,以國際連,結型,深耕,型,USR,計畫,《,鄰家,好,漁,》,，,展現,高,科大,投入,地方,創生,、,SDGs,永續,議題,的,能量,。,ADB,是,台灣,重點,參,與, ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import numpy as np
import jieba
fp = open("alldata.txt","r",encoding="utf-8")
alldata = fp.read()

tt = jieba.cut(alldata)
terms = list()
for t in tt:
    terms.append(t)
alldata = ",".join(terms)


mask = np.array(Image.open('cloud.jpg'))
wordcloud = WordCloud(background_color="white", width=1000, height=860, margin=2, font_path="SimHei.ttf", mask=mask).generate(alldata)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
